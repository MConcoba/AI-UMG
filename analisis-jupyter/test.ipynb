# %% [markdown]
# # TEST

# %% [markdown]
# ## Nivel 2

# %% [markdown]
# - Lista

# %% [markdown]
# - **Negrita** *cursiva*

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y)
plt.title("Gráfico de Línea")
plt.show()
